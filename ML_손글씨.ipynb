# %%
import matplotlib.pyplot as plt
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
import matplotlib.pyplot as plt
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split


digits = datasets.load_digits()
plt.imshow(digits.images[0], cmap=plt.cm.gray_r, interpolation='nearest')

# %%
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
X = digits.images.reshape((len(digits.images), -1))  # (1797, 64)
y = digits.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#로지스틱 회귀분석
lr_clf = LogisticRegression(max_iter=5000)  # 반복횟수 충분히 설정
lr_clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
y_pred = log_reg.predict(X_test)

# %%
print("로지스틱 회귀 정확도:", metrics.accuracy_score(y_test, y_pred))
# Out:
# 로지스틱 회귀 정확도: 0.9685185185185186

# %%
#결정나무
dt_clf = DecisionTreeClassifier(random_state=42)

# %%
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = dt_clf.predict(X_test)

# %%
print("Decision Tree 정확도:", metrics.accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree 정확도: 0.8425925925925926

# %%
#랜덤포레스트

rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_clf.predict(X_test)

# %%
print("Random Forest 정확도:", metrics.accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest 정확도: 0.975925925925926

# %%
images_and_predictions = list(zip(digits.images[len(X_train):], y_pred_rf))

plt.figure(figsize=(8, 6))
for index, (image, prediction) in enumerate(images_and_predictions[:8]):
    plt.subplot(2, 4, index + 1)
    plt.axis("off")
    plt.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    plt.title(f"Pred: {prediction}")
plt.show()

# %%
#KNN

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6)

# %%
dt_knn = knn.fit(X_train, y_train)

# %%
y_pred_knn = dt_knn.predict(X_test)

# %%
print("KNN 정확도:", metrics.accuracy_score(y_test, y_pred_knn))
# Out:
# KNN 정확도: 0.9944444444444445
